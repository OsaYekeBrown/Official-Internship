# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Urban_Park_Ranger_Animal_Condition_Response_Manhattan.csv')
#data.e = pd.write_csv('Urban_Park_Ranger_Animal_Condition_Response.csv')

# %%
data.head()
# Out:
#   Date and Time of initial call Date and time of Ranger response    Borough  \
# 0                  5/9/19 11:30                     5/9/19 15:00  Manhattan
# 1                 4/17/19 13:00                    4/17/19 13:30  Manhattan
# 2                 5/22/19 14:00                    5/22/19 14:15  Manhattan
# 3                 5/17/19 16:15                    5/17/19 16:15  Manhattan
# 4                 5/14/19 15:54                    5/14/19 16:00  Manhattan
#
#               Property                                           Location  \
# 0         Central Park  Large Bald Cyprus on South East Corner of Harl...
# 1         Central Park              Near Boathouse Restaurant Parking Lot
# 2         Central Park                               5th Ave and 108th St
# 3  Madison Square Park                                                NaN
# 4         Central Park                              72nd St/ 5th ave wall
#
# ...

# %%
data.shape
# Out:
# (475, 22)

# %%
data['Property'].unique()
# Out:
# array(['Central Park', 'Madison Square Park', 'Mercer Playground',
#        'Inwood Hill Park', 'Highbridge Recreation Center',
#        'Morningside park', 'Morningside Park', 'West Harlem Piers',
#        'Hudson Park', 'Hudson River Park', 'Riverside Park',
#        'Stuyvesant Square', 'Hester St. Playground', 'Bryant Park',
#        'St. Nicholas Park', 'Thomas Jefferson Recreation Center',
#        'Battery Park City', 'John V. Lindsay East River Park',
#        'Fort Tryon Park', 'Sherman Creek', "Randall's Island Park",
#        'Churchill School', 'Washington Market Park',
#        'Fort Washington Park', 'Sutton Place Park', 'Central  Park',
#        'Isham Park', 'Sheltering Arms Playground', 'James Finley Walk',
#        'Carl Schurz Park', 'Jacob H. Schiff Playground',
#        'Theodore Roosevelt Park', 'Abingdon Square',
#        'Playground 103 CIII', 'J. Hood Wright Park',
#        'Washington Square Park', 'Tompkins Square Park',
# ...

# %%
number_of_properties = data['Property'].nunique()
print("There are "+str(number_of_properties)+" properties where wildlife have been spotted and the identifier"+
      " called the police")
# Out:
# There are 51 properties where wildlife have been spotted and the identifier called the police

# %%
number_of_species = data['Species Description'].nunique()

# %%
data['Species Description'].nunique()
print("There are "+str(number_of_species)+" types of wildlife that have been spotted and the identifier"+
      " called the police")
# Out:
# There are 62 types of wildlife that have been spotted and the identifier called the police

# %%
data.head()
# Out:
#   Date and Time of initial call Date and time of Ranger response    Borough  \
# 0                  5/9/19 11:30                     5/9/19 15:00  Manhattan
# 1                 4/17/19 13:00                    4/17/19 13:30  Manhattan
# 2                 5/22/19 14:00                    5/22/19 14:15  Manhattan
# 3                 5/17/19 16:15                    5/17/19 16:15  Manhattan
# 4                 5/14/19 15:54                    5/14/19 16:00  Manhattan
#
#               Property                                           Location  \
# 0         Central Park  Large Bald Cyprus on South East Corner of Harl...
# 1         Central Park              Near Boathouse Restaurant Parking Lot
# 2         Central Park                               5th Ave and 108th St
# 3  Madison Square Park                                                NaN
# 4         Central Park                              72nd St/ 5th ave wall
#
# ...

# %%
data['Location'].unique()
# Out:
# array(['Large Bald Cyprus on South East Corner of Harlem Meer, close to 106th St and 5th Ave',
#        'Near Boathouse Restaurant Parking Lot', '5th Ave and 108th St',
#        nan, '72nd St/ 5th ave wall',
#        'near 100th St Pool, closer to 104th street, on rock outcrop',
#        'Mercer st & Bleeker st',
#        'Gaelic field, southeastern corner closer to the Marsh side, at the base of a London Plane tree GPS (40.873125, -73.921672)',
#        '311 caller did not leave detailed location', '113th near steps',
#        '125 street and West Harlem Piers Park', 'Pier 51',
#        '12th street and West Street', 'Harlem Meer 40.796582, -73.950043',
#        'Harlem Meer', "Linda's Lawn", 'The caves', 'Dykman Ball Fields',
#        'M & O HQ District 12', "Dana Center Men's Restroom",
#        'Dyckman Street and Staff Street',
#        '151 St and Riverside PK by the bridge area',
#        'Near the dog run at Isham Avenue and Seaman Street',
# ...

# %%
data['Location'].nunique()
# Out:
# 424

# %%
data['Species Status'].unique()
# Out:
# array(['Native', 'Exotic', 'Domestic', nan, 'Invasive'], dtype=object)

# %%
data['Call Source'].unique()
# Out:
# array(['Public', 'Central', 'Employee',
#        'Conservancies/"Friends of" Groups', 'Other', 'Observed by Ranger'],
#       dtype=object)

# %%
data['Animal Condition'].value_counts()
# Out:
# Unhealthy    187
# Healthy       81
# DOA           51
# Injured       36
# Name: Animal Condition, dtype: int64

# %%
data['Final Ranger Action'].value_counts()
# Out:
# ACC                              188
# Unfounded                        107
# Relocated/Condition Corrected     64
# Monitored Animal                  47
# Rehabilitator                     31
# Advised/Educated others           29
# Submitted for DEC Testing          9
# Name: Final Ranger Action, dtype: int64

# %%
data['PEP Response'].unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
data['Rehabilitator'].unique()
# Out:
# array([nan, 'Wild Bird Fund', 'Wild Bird Fund, Manhattan',
#        'Wild Bird Fund Manhattan', 'WBF', 'Bobby Horvath',
#        'Wildbird Fund', 'Animal Medical Center Manhattan', 'WINOR',
#        'Animal Medical Center'], dtype=object)

# %%
data['Police Response'].value_counts()
# Out:
# False    461
# True      12
# Name: Police Response, dtype: int64

# %%
data['ESU Response'].unique()
# Out:
# array([False,  True])

# %%
data['ACC Intake Number'].unique()
# Out:
# array([nan, '40180/40181/40182', '46961', '48438', '51926', '39503',
#        '54198', '38182', '37960', '37961', '37962', '38398', '37963',
#        '53674', '56886', '64890', '55993', '60355', '55405', '60330',
#        '50469', '37171', '39582', '36328', '37022', '39704', '39793',
#        '39840', '54451', '59915', '37704', '31565', '34935', '35069',
#        '35372', '35529', '35650', '35692', '35796', '35899', '36012',
#        '36013', '36023', '36209', '36569', '36572', '36670', '36669',
#        '36723', '36786', '36918', '37018', '37021', '37364', '37377',
#        '37395', '37471', '37522', '37618', '37609', '37611', '37610',
#        '37653', '37702', '37743', '38024', '38145', '38142', '38337',
#        '38336', '38388', '38474', '38473', '38513', '38616', '38767',
#        '38879', '38875', '38926', '38927', '39000', '39050',
#        '1-1-1607314261', '39257; 39258', '39304', '39530, 39531', '40061',
# ...

# %%
data.head()
# Out:
#   Date and Time of initial call Date and time of Ranger response    Borough  \
# 0                  5/9/19 11:30                     5/9/19 15:00  Manhattan
# 1                 4/17/19 13:00                    4/17/19 13:30  Manhattan
# 2                 5/22/19 14:00                    5/22/19 14:15  Manhattan
# 3                 5/17/19 16:15                    5/17/19 16:15  Manhattan
# 4                 5/14/19 15:54                    5/14/19 16:00  Manhattan
#
#               Property                                           Location  \
# 0         Central Park  Large Bald Cyprus on South East Corner of Harl...
# 1         Central Park              Near Boathouse Restaurant Parking Lot
# 2         Central Park                               5th Ave and 108th St
# 3  Madison Square Park                                                NaN
# 4         Central Park                              72nd St/ 5th ave wall
#
# ...
