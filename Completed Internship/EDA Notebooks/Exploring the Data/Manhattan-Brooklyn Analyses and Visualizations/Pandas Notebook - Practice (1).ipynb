# %% [markdown]
# Step 1: Import pandas

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Create dataframe from CSV file

# %% [markdown]
# Use parse_dates to convert date and time data into datetime type.
#
# Example: data = pd.read_csv('Urban_Park_Ranger_Animal_Condition_Response.csv',
#                    parse_dates = ['Date and Time of initial call', 'Date and time of Ranger response'])

# %%
data = pd.read_csv('Urban_Park_Ranger_Animal_Condition_Response_Manhattan_Ruth.csv',
                   parse_dates = ['Date and Time of initial call', 'Date and time of Ranger response'])

# %% [markdown]
# Step 3: What data do you have?

# %% [markdown]
# Try: .info() .head() .tail() .shape .nunique() .unique()
#
# Note: .nunique() and .unique() only work on a Series (aka, a column).
#
# Example: data["Property"].unique() and data["Property"].nunique().

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 22 columns):
# Date and Time of initial call       475 non-null datetime64[ns]
# Date and time of Ranger response    475 non-null datetime64[ns]
# Borough                             475 non-null object
# Property                            475 non-null object
# Location                            443 non-null object
# Species Description                 468 non-null object
# Call Source                         475 non-null object
# Species Status                      469 non-null object
# Animal Condition                    355 non-null object
# Duration of Response                475 non-null float64
# Age                                 475 non-null object
# Animal Class                        475 non-null object
# 311SR Number                        262 non-null object
# Final Ranger Action                 475 non-null object
# # of Animals                        472 non-null float64
# ...

# %%
data["Property"].unique()
# Out:
# array(['Central Park', 'Madison Square Park', 'Mercer Playground',
#        'Inwood Hill Park', 'Highbridge Recreation Center',
#        'Morningside park', 'Morningside Park', 'West Harlem Piers',
#        'Hudson Park', 'Hudson River Park', 'Riverside Park',
#        'Stuyvesant Square', 'Hester St. Playground', 'Bryant Park',
#        'St. Nicholas Park', 'Thomas Jefferson Recreation Center',
#        'Battery Park City', 'John V. Lindsay East River Park',
#        'Fort Tryon Park', 'Sherman Creek', "Randall's Island Park",
#        'Churchill School', 'Washington Market Park',
#        'Fort Washington Park', 'Sutton Place Park', 'Central  Park',
#        'Isham Park', 'Sheltering Arms Playground', 'James Finley Walk',
#        'Carl Schurz Park', 'Jacob H. Schiff Playground',
#        'Theodore Roosevelt Park', 'Abingdon Square',
#        'Playground 103 CIII', 'J. Hood Wright Park',
#        'Washington Square Park', 'Tompkins Square Park',
# ...

# %% [markdown]
# Step 4: Practice accessing data by column label

# %% [markdown]
# Example: data["Property"]

# %% [markdown]
# Step 5: Practice accessing data by row: .iloc (locates by numberical index); .loc (locates by name)

# %% [markdown]
# Note: .loc() only works when your data frame has a defined index.
#
# Example: data.loc['2019-05-09 11:30:00'] produces an error: KeyError: 'the label [2019-05-09 11:30:00] is not in the [index]')

# %%
data['Property'].iloc[3]
# Out:
# 'Madison Square Park'

# %% [markdown]
# Step 6: Practice accessing by condition: dataframe[condition] where condition is dataframe[column] == "something"
#
# Example: data[data["Property"] == "Central Park"]

# %%
data[data["Property"]=='private property']
# Out:
#     Date and Time of initial call Date and time of Ranger response    Borough  \
# 471           2018-11-30 15:00:00              2018-11-30 15:00:00  Manhattan
#
#              Property         Location Species Description Call Source  \
# 471  private property  Lower Manhattan            Woodcock      Public
#
#     Species Status Animal Condition  Duration of Response  ... 311SR Number  \
# 471         Native              NaN                  0.25  ...          NaN
#
#          Final Ranger Action # of Animals PEP Response  Animal Monitored  \
# 471  Advised/Educated others          1.0        False             False
#
#     Rehabilitator Hours spent monitoring Police Response  ESU Response  \
# 471           NaN                    NaN           False         False
#
#     ACC Intake Number
# 471               NaN
#
# [1 rows x 22 columns]

# %% [markdown]
# Step 7: Practice accessing by condition, using logical operators: | and &

# %% [markdown]
# Example: data[(data["Property"] == "Central Park") & (data["Species Status"] == "Native")]

# %%
data[(data["Property"] == "Central Park") & (data["Species Status"] == "Native")]
# Out:
#     Date and Time of initial call Date and time of Ranger response    Borough  \
# 0             2019-05-09 11:30:00              2019-05-09 15:00:00  Manhattan
# 1             2019-04-17 13:00:00              2019-04-17 13:30:00  Manhattan
# 2             2019-05-22 14:00:00              2019-05-22 14:15:00  Manhattan
# 4             2019-05-14 15:54:00              2019-05-14 16:00:00  Manhattan
# 5             2018-11-21 09:30:00              2018-11-21 10:30:00  Manhattan
# 14            2019-01-30 02:11:00              2019-01-30 14:40:00  Manhattan
# 15            2018-11-28 10:15:00              2018-11-28 13:30:00  Manhattan
# 26            2019-02-08 14:40:00              2019-02-08 14:55:00  Manhattan
# 28            2019-03-16 15:40:00              2019-03-16 15:50:00  Manhattan
# 30            2019-04-02 11:00:00              2019-04-02 11:20:00  Manhattan
# 31            2018-11-13 10:00:00              2018-11-13 12:00:00  Manhattan
# ...

# %% [markdown]
# Step 8: Practice group by (split data into groups based on some criteria and apply function

# %% [markdown]
# You call .groupby() and pass the name of the column you want to group on. Then, you use ["column"] to specify the column(s) on which you want to perform the actual function.
#
# You can pass a lot more than just a single column name to .groupby() as the first argument.

# %% [markdown]
# Examples:
#
# data.groupby("Property")["Location"].count()

# %% [markdown]
# data.groupby(["Property", "Species Status"])["Animal Condition"].count()

# %%
#q = data[data["Property"]!='Central Park'] #.value_counts().head(5).plot(kind='bar')#
data['Property'].value_counts().head(5).plot(kind='bar',colors='red') # :) 
plt.title("What were the Main Places in Manhattan Where Urban Wildlife were Spotted?")
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt 
explode = (0.05,0.05,0.05,0.05,) 
π = data['Animal Condition'].value_counts()
π.plot(kind='pie',explode=explode,startangle=40,shadow=True,autopct='%1.1f%%',pctdistance=0.6,label='')
plt.legend(bbox_to_anchor=(1.2, 1.0))
plt.title("What were the Conditions of the Urban Wildlife When Found by the Police?")

# %%
import matplotlib.pyplot as plt 

explode = (0.15,0.15,0.15,0.15,0.15,0.15,0.15) 

π = data['Final Ranger Action'].value_counts()

π.plot(kind='pie',
       explode=explode,
       startangle=40,
       shadow=True,
       autopct='%1.1f%%',
       pctdistance=0.6,
       label='')

plt.legend(bbox_to_anchor=(2.5, .8))
plt.title("What Were the Final Actions of Rangers Who Found Urban Wildlife in Manhattan?")
# Out:
# Text(0.5, 1.0, 'What Were the Final Actions of Rangers Who Found Urban Wildlife in Manhattan?')

# %% [markdown]
# ##### data.groupby(["Borough", "Species Status"])["Animal Condition"].count().plot.pie()
# plt.show()

# %%
data['Final Ranger Action'].unique() #What is DEC (Depart. of Environ. Cons.) Testing? ACC (Care unit) 
#data.head(2)
# Out:
# array(['Relocated/Condition Corrected', 'Rehabilitator',
#        'Advised/Educated others', 'Unfounded', 'ACC',
#        'Submitted for DEC Testing', 'Monitored Animal'], dtype=object)

# %%
#data.groupby(["Borough", "Species Status"])["Animal Condition"].count().plot(kind='barh')

# %%
data.groupby(["Borough", "Call Source"])["Animal Condition"].count().plot(kind="bar",colors='red')

# %%
data["# of Animals"].hist()

# %%
data['Hours spent monitoring'].hist()

# %%
data["Duration of Response"].hist()

# %%
data['Age'].value_counts()
# Out:
# Adult                      302
# Juvenile                   142
# Infant                      25
# Adult;#Juvenile;#Infant      3
# Adult;#Juvenile              3
# Name: Age, dtype: int64

# %%
data['Animal Class'].value_counts()
# Out:
# Small Mammals-RVS                   327
# Birds                                55
# Raptors                              35
# Small Mammals-non RVS                27
# Domestic                             14
# Terrestrial Reptile or Amphibian      8
# Coyotes                               3
# Deer                                  3
# Small Mammals-RVS;#Raptors            1
# Marine Mammals-seals only             1
# Domestic;#Birds                       1
# Name: Animal Class, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 22 columns):
# Date and Time of initial call       475 non-null datetime64[ns]
# Date and time of Ranger response    475 non-null datetime64[ns]
# Borough                             475 non-null object
# Property                            475 non-null object
# Location                            443 non-null object
# Species Description                 468 non-null object
# Call Source                         475 non-null object
# Species Status                      469 non-null object
# Animal Condition                    355 non-null object
# Duration of Response                475 non-null float64
# Age                                 475 non-null object
# Animal Class                        475 non-null object
# 311SR Number                        262 non-null object
# Final Ranger Action                 475 non-null object
# # of Animals                        472 non-null float64
# ...

# %%
s = data.groupby(['PEP Response','Species Status']).size().unstack()
p = data.groupby(['Animal Monitored','Species Status']).size().unstack()
l = data.groupby(['Police Response','Species Status']).size().plot
c = data.groupby(['Police Response','Species Status']).size().unstack()

# %%
s.plot.bar(stacked=True)
p.plot.bar(stacked=True)
l.plot.bar(stacked=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-71a3f8d691fa> in <module>
#       1 s.plot.bar(stacked=True)
#       2 p.plot.bar(stacked=True)
# ----> 3 l.plot.bar(stacked=True)
#
# AttributeError: 'SeriesPlotMethods' object has no attribute 'plot'
